# %% [markdown]
# <a href="https://colab.research.google.com/github/HariPranav/mlprog/blob/main/Prog8WithComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Prog 8 . Similar to 10 as we have plt .
# get the data into two columns v1 and v2 in f1 and f2
# use zip to map to similar attributes in the cluster
# plt f1,f1,c=black,s=10
# Apply kmeans algo , fit the model ,label predict 
# plt , x[:,0] x[:,1] ,c=label ,s=10
# plt kmeans.cluster_center[:,0] ,kmeans.cluster_center[:,1] ,c=label ,marker='*' for centroid 

# For GM , same procedure

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.mixture import GaussianMixture
from sklearn.cluster import KMeans

# %%
dp=pd.read_csv("/content/drive/MyDrive/datasets/8-Kmeans_EM.csv")
dp
# Out:
#              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# ...         ...        ...
# 2995  85.652800  -6.461061
# 2996  82.770880  -2.373299
# 2997  64.465320 -10.501360
# 2998  90.722820 -12.255840
# 2999  64.879760 -24.877310
#
# [3000 rows x 2 columns]

# %%
# since it has 2 rows take it as v1 and v2
f1=np.array(dp['V1'])

# %%
f2=np.array(dp['V2'])

# %%
x=np.array(list(zip(f1,f2)))

# %%
plt.scatter(f1,f2,c="black",s=10)

# %%
# apply k means 

km=KMeans(n_clusters=3)
km=km.fit(x)
label=km.predict(x)

plt.scatter(x[:,0],x[:,1],c=label,s=10)
plt.scatter(km.cluster_centers_[:,0],km.cluster_centers_[:,1],marker="*",s=10)

# %%
# apply gaussian mixture

gm=GaussianMixture(n_components=3)
gm.fit(x)
label=gm.predict(x)

print("The probability is ",gm.predict_proba(x))
print("The mean is ",gm.means_)
print("the covraince is ",gm.covariances_)
# Out:
# The probability is  [[1.51560970e-12 2.47857809e-09 9.99999998e-01]
#  [4.99388810e-06 3.50898583e-07 9.99994655e-01]
#  [3.06364433e-10 1.79826264e-10 1.00000000e+00]
#  ...
#  [5.88532728e-13 9.99999967e-01 3.31608645e-08]
#  [1.18181069e-16 1.00000000e+00 3.40814080e-15]
#  [1.17363874e-17 9.99999999e-01 7.83207859e-10]]
# The mean is  [[ 40.68585643  59.70939105]
#  [ 69.89436808 -10.11243325]
#  [  9.46516999  10.71326558]]
# the covraince is  [[[103.11540751  -1.82258688]
#   [ -1.82258688  94.29478126]]
#
#  [[110.42521599  -0.60038245]
#   [ -0.60038245 106.47434137]]
#
#  [[103.72485985   3.83148201]
#   [  3.83148201  96.80338694]]]
